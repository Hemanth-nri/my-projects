# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemanth-nri/my-projects/blob/main/Retail_Transaction_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Python./retail_transactions.csv')

Revenue=df['Price'].sum()

# %%
df
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 0           T001      2024-01-01      102        1646        545
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# ..           ...             ...      ...         ...        ...
# 95          T096      2024-04-05      101        1918        559
# 96          T097      2024-04-06      104        1190        579
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 0      Electronics         1    150      Credit      15.0
# 1             Toys         2    317       Debit      10.0
# ...

# %%
Most_purchase=df['ProductCategory'].mode()
Most_purchase
# Out:
# 0    Furniture
# Name: ProductCategory, dtype: object

# %%
A_tranc=df['Price'].mean()
A_tranc
# Out:
# 282.15

# %%
Filter = df[df['Price'] > 150]
Filter
# Out:
#    TransactionID TransactionDate  StoreID  CustomerID  ProductID  \
# 1           T002      2024-01-02      103        1226        542
# 2           T003      2024-01-03      102        1515        593
# 3           T004      2024-01-04      103        1793        560
# 4           T005      2024-01-05      105        1864        523
# 5           T006      2024-01-06      103        1836        515
# ..           ...             ...      ...         ...        ...
# 94          T095      2024-04-04      103        1980        529
# 95          T096      2024-04-05      101        1918        559
# 97          T098      2024-04-07      102        1932        504
# 98          T099      2024-04-08      103        1285        587
# 99          T100      2024-04-09      101        1602        574
#
#    ProductCategory  Quantity  Price PaymentType  Discount
# 1             Toys         2    317       Debit      10.0
# 2      Electronics         5    165       Debit       NaN
# ...

# %%
Spendings =df.groupby('TransactionID')['Price'].sum()
Top_3= Spendings.sort_values(ascending=True).tail(3)
Top_3
# Out:
# TransactionID
# T004    496
# T074    498
# T008    500
# Name: Price, dtype: int64

# %%
Grt_filter1=df['Price'].mode()
Grt_filter1
# Out:
# 0    109
# 1    120
# 2    166
# 3    170
# 4    201
# 5    449
# 6    480
# 7    495
# Name: Price, dtype: int64

# %%
# prompt: Suggest a name for this project
